# %% [markdown]
# # Natural Gas Data Cleaning
# ### What we are building?
# We will be cleaning the raw data that we collected. We want to clean this data to create an efficient dataset that we can then analyze.
#
# ### Tasks
# - Importing Modules
# - Importing Collected Data
# - Defining the Data
# - Converting Data to proper types
# - Output Cleaned Dataset
#
# ### Importing Modules
# - Pandas (https://pandas.pydata.org/docs/reference/index.html)
# - Csv (https://docs.python.org/3/library/csv.html)

# %%
# Importing Modules
import pandas as pd

# %% [markdown]
# ### Importing Collected Data
# We are now importing the dataset we collected using [My Web Scraping Bot](https://git.io/JJTtq)

# %%
#Importing Data
data = pd.read_csv('data0.csv')
data.head() #Showing Sample of Dataset
# Out:
#        Dates  Import Prices  Import Prices By Pipeline  Import Prices As LNG  \
# 0  2000-01-1           2.44                       2.42                  2.85
# 1  2000-02-1           2.60                       2.57                  3.33
# 2  2000-03-1           2.61                       2.60                  2.77
# 3  2000-04-1           2.86                       2.85                  2.90
# 4  2000-05-1           3.05                       3.05                  3.06
#
#    Export Prices  Export Prices By Pipeline  Export Prices As LNG  \
# 0           2.95                        NaN                   NaN
# 1           3.05                        NaN                   NaN
# 2           3.00                        NaN                   NaN
# 3           3.37                        NaN                   NaN
# 4           3.52                        NaN                   NaN
#
#    Citygate Prices  Residential Prices  Commercial Prices  ...  \
# ...

# %% [markdown]
# ### Cleaning Data to desired format

# %%
# Cleaning Data
## Prices
ip = data['Import Prices'].values
ip_bp = data['Import Prices By Pipeline'].values
ip_lng = data['Import Prices As LNG'].values
ep = data['Export Prices'].values
ep_bp = data['Export Prices By Pipeline'].values
ep_lng = data['Export Prices As LNG'].values
cg_p = data['Citygate Prices'].values
res_p = data['Residential Prices'].values
comm_p = data['Commercial Prices'].values
indust_p = data['Industrial Prices'].values
elec_pow_p = data['Electric Power Prices'].values
## Production
gw = data['Gross Withdrawals'].values
mp = data['Marketed Production'].values
ngpl = data['NGPL Production'].values
dry = data['Dry Production'].values
## Import/Export Volume
iv = data['Import Volume(Mcf)'].values
iv_bp = data['Import Volume By Pipeline'].values
iv_lng = data['Import Volume As LNG'].values
ev = data['Export Volume(Mcf)'].values
ev_bp = data['Export Volume By Pipeline'].values
ev_lng = data['Export Volume As LNG'].values
## Storage
tc = data['Total Capacity'].values
gs = data['Gas in Storage'].values
bg = data['Base Gas'].values
wg = data['Working Gas'].values
inj = data['Injections'].values
withd = data['Withdrawals'].values
net_withd = data['Net Withdrawals'].values
## Consumption
total_consump = data['Total Consumption'].values
lpf_consump = data['Lean & Plant Fuel'].values
pdu_consump = data['Pipeline & Distribution Use'].values
d2c_consump = data['Delivered to Consumers'].values
res_consump = data['Residential'].values
com_consump = data['Commercial'].values
ind_consump = data['Industrial'].values
vf_consump = data['Vehicle Fuel'].values
ep_consump = data['Electric Power'].values
## Dates
dates = data['Dates']
